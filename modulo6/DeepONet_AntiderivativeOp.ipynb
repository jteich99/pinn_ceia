# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/MyDrive/CursoPINN-CEIA-UBA/20253B/Material didáctico/Modulo6
# Out:
# /content/drive/MyDrive/CursoPINN-CEIA-UBA/20253B/Material didáctico/Modulo6

# %% [markdown]
# # Definición de las redes "branch" y "trunk", y de la DeepONet

# %%
# Define the Branch Network
class BranchNet(nn.Module):
    def __init__(self, branchNet_params):
        super(BranchNet, self).__init__()
        self.Device = branchNet_params["Device"]
        self.InputDimensions = branchNet_params["InputDimensions"]
        self.OutputDimensions = branchNet_params["OutputDimensions"]
        self.NumberOfNeurons = branchNet_params["NumberOfNeurons"]
        self.NumberOfHiddenLayers = branchNet_params["NumberOfHiddenLayers"]
        self.ActivationFunction = branchNet_params["ActivationFunction"]
        self.InputLayer = nn.Linear(self.InputDimensions, self.NumberOfNeurons)
        self.HiddenLayers = nn.ModuleList(
            [nn.Linear(self.NumberOfNeurons, self.NumberOfNeurons) for _ in range(self.NumberOfHiddenLayers - 1)])
        self.OutputLayer = nn.Linear(self.NumberOfNeurons, self.OutputDimensions)

        #self.init_xavier()

    def forward(self, x):
        output = self.ActivationFunction(self.InputLayer(x))
        for k, l in enumerate(self.HiddenLayers):
            output = self.ActivationFunction(l(output))
        output = self.OutputLayer(output)
        return output

    def init_xavier(self):
        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                # gain = nn.init.calculate_gain('tanh')
                gain = 1
                torch.nn.init.xavier_uniform_(m.weight, gain=gain)
                torch.nn.init.uniform_(m.bias, 0, 1)

        self.apply(init_weights)

# Define the Trunk Network
class TrunkNet(nn.Module):
    def __init__(self, trunkNet_params):
        super(TrunkNet, self).__init__()
        self.Device = trunkNet_params["Device"]
        self.InputDimensions = trunkNet_params["InputDimensions"]
        self.OutputDimensions = trunkNet_params["OutputDimensions"]
        self.NumberOfNeurons = trunkNet_params["NumberOfNeurons"]
        self.NumberOfHiddenLayers = trunkNet_params["NumberOfHiddenLayers"]
        self.ActivationFunction = trunkNet_params["ActivationFunction"]
        self.InputLayer = nn.Linear(self.InputDimensions, self.NumberOfNeurons)
        self.HiddenLayers = nn.ModuleList(
            [nn.Linear(self.NumberOfNeurons, self.NumberOfNeurons) for _ in range(self.NumberOfHiddenLayers - 1)])
        self.OutputLayer = nn.Linear(self.NumberOfNeurons, self.OutputDimensions)

        #self.init_xavier()

    def forward(self, x):
        output = self.ActivationFunction(self.InputLayer(x))
        for k, l in enumerate(self.HiddenLayers):
            output = self.ActivationFunction(l(output))
        output = self.OutputLayer(output)
        return output

    def init_xavier(self):
        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                # gain = nn.init.calculate_gain('tanh')
                gain = 1
                torch.nn.init.xavier_uniform_(m.weight, gain=gain)
                torch.nn.init.uniform_(m.bias, 0, 1)

        self.apply(init_weights)


# Define the DeepONet
class DeepONet(nn.Module):
    def __init__(self, branch_net, trunk_net):
        super(DeepONet, self).__init__()
        self.branch_net = branch_net
        self.trunk_net = trunk_net

    def forward(self, branch_input, trunk_input):
        # Get branch and trunk outputs
        branch_output = self.branch_net(branch_input)  # Shape: [batch_size, branch_output_dim]
        trunk_output = self.trunk_net(trunk_input)    # Shape: [batch_size, trunk_output_dim]

        # Combine the outputs (dot product across the last dimension)
        combined_output = torch.sum(branch_output*trunk_output, dim=-1).view(-1, 1)

        #print(f'branch_output: {branch_output.shape}')
        #print(f'trunk_output: {trunk_output.shape}')
        #print(f'combined_output: {combined_output.shape}')

        return combined_output

# %% [markdown]
# # Data

# %%
# Download training data
d = np.load("antiderivative_unaligned_train.npz", allow_pickle=True)
v_train = torch.from_numpy(d["X_train0"]).to(torch.float32).to(device) # Input forcing perturbation at fixed sensors
x_train = torch.from_numpy(d["X_train1"]).to(torch.float32).to(device) # Desired output locations
u_train = torch.from_numpy(d["y_train"]).to(torch.float32).to(device) # Output field at locations x_train

print("Shape of v_train: ", v_train.shape)
print("Shape of x_train: ", x_train.shape)
print("Shape of u_train: ", u_train.shape)

# Download testing data
d = np.load("antiderivative_unaligned_test.npz", allow_pickle=True)
v_test = torch.from_numpy(d["X_test0"]).to(torch.float32).to(device)
x_test = torch.from_numpy(d["X_test1"]).to(torch.float32).to(device)
u_test = torch.from_numpy(d["y_test"]).to(torch.float32).to(device)

print("Shape of v_test: ", v_test.shape)
print("Shape of x_test: ", x_test.shape)
print("Shape of u_test: ", u_test.shape)

idx_test = np.random.choice(len(x_test), 100, replace=False)
# Out:
# Shape of v_train:  torch.Size([10000, 100])
# Shape of x_train:  torch.Size([10000, 1])
# Shape of u_train:  torch.Size([10000, 1])
# Shape of v_test:  torch.Size([100000, 100])
# Shape of x_test:  torch.Size([100000, 1])
# Shape of u_test:  torch.Size([100000, 1])

# %%
rows = np.random.randint(0, 10000, 5)
for row in rows:
    plt.scatter(np.arange(0, v_train.shape[1]), v_train[row, :].data.cpu().detach().numpy(), s=1, label=f'row:{row}')

plt.xlabel('Indices')
plt.ylabel('v(x)')
plt.legend()
plt.show()

# %%
plt.scatter(x_train.data.cpu().detach().numpy(), u_train.data.cpu().detach().numpy(), s=1)
plt.xlabel('x')
plt.ylabel('u(x)')
plt.show()

# %% [markdown]
# # Main execution

# %%
# Initialization parameters
branchNet_params = {
    "Device": device,
    "InputDimensions": 100,
    "OutputDimensions": 100,
    "NumberOfNeurons": 40,
    "NumberOfHiddenLayers": 2,
    "ActivationFunction": nn.Tanh()
}

trunkNet_params = {
    "Device": device,
    "InputDimensions": 1,
    "OutputDimensions": 100,
    "NumberOfNeurons": 40,
    "NumberOfHiddenLayers": 2,
    "ActivationFunction": nn.Tanh()
}

# %%
# Build model
branch_net = BranchNet(branchNet_params).to(device)
trunk_net = TrunkNet(trunkNet_params).to(device)
model = DeepONet(branch_net, trunk_net).to(device)

# %%
# Training Setup
epochs = 20000
lr = 1e-4
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
train_err_list = []
test_err_list = []
train_loss_list = []
test_loss_list = []
for epoch in range(epochs):

    # Train stage
    model.train()
    optimizer.zero_grad()
    u_train_pred = model.forward(v_train, x_train)
    train_loss = criterion(u_train_pred, u_train)
    train_loss.backward()
    optimizer.step()
    train_err = np.mean(np.linalg.norm(u_train.data.cpu().detach().numpy() - u_train_pred.data.cpu().detach().numpy(), 2, axis=1)/\
                np.linalg.norm(u_train.data.cpu().detach().numpy(), 2, axis=1))
    train_loss_list.append(train_loss.item())
    train_err_list.append(train_err.item())

    # Test stage
    model.eval()
    with torch.no_grad():
        u_test_pred = model.forward(v_test[idx_test, :], x_test[idx_test, :])
        test_loss = criterion(u_test_pred, u_test[idx_test, :])
        test_err = np.mean(np.linalg.norm(u_test[idx_test, :].data.cpu().detach().numpy() - u_test_pred.data.cpu().detach().numpy(), 2, axis=1)/\
                    np.linalg.norm(u_test[idx_test, :].data.cpu().detach().numpy(), 2, axis=1))
        test_loss_list.append(test_loss.item())
        test_err_list.append(test_err.item())

    if epoch % 100 == 0:
        print(f"Epoch {epoch+1}, Training Loss: {train_loss:.6f}")
        print(f"Epoch {epoch+1}, Test Loss: {test_loss:.6f}")
# Out:
# Epoch 1, Training Loss: 0.177775
# Epoch 1, Test Loss: 0.173869
# Epoch 101, Training Loss: 0.010777
# Epoch 101, Test Loss: 0.012970
# Epoch 201, Training Loss: 0.009648
# Epoch 201, Test Loss: 0.011768
# Epoch 301, Training Loss: 0.008872
# Epoch 301, Test Loss: 0.010758
# Epoch 401, Training Loss: 0.008102
# Epoch 401, Test Loss: 0.009787
# Epoch 501, Training Loss: 0.007135
# Epoch 501, Test Loss: 0.008680
# Epoch 601, Training Loss: 0.005941
# Epoch 601, Test Loss: 0.007434
# Epoch 701, Training Loss: 0.004926
# Epoch 701, Test Loss: 0.006346
# Epoch 801, Training Loss: 0.004437
# Epoch 801, Test Loss: 0.005678
# Epoch 901, Training Loss: 0.004251
# Epoch 901, Test Loss: 0.005374
# Epoch 1001, Training Loss: 0.004155
# Epoch 1001, Test Loss: 0.005220
# Epoch 1101, Training Loss: 0.004087
# Epoch 1101, Test Loss: 0.005116
# Epoch 1201, Training Loss: 0.004031
# Epoch 1201, Test Loss: 0.005037
# Epoch 1301, Training Loss: 0.003983
# Epoch 1301, Test Loss: 0.004974
# Epoch 1401, Training Loss: 0.003939
# Epoch 1401, Test Loss: 0.004919
# Epoch 1501, Training Loss: 0.003898
# Epoch 1501, Test Loss: 0.004867
# Epoch 1601, Training Loss: 0.003857
# Epoch 1601, Test Loss: 0.004814
# Epoch 1701, Training Loss: 0.003814
# Epoch 1701, Test Loss: 0.004756
# Epoch 1801, Training Loss: 0.003766
# Epoch 1801, Test Loss: 0.004691
# Epoch 1901, Training Loss: 0.003707
# Epoch 1901, Test Loss: 0.004611
# Epoch 2001, Training Loss: 0.003628
# Epoch 2001, Test Loss: 0.004508
# Epoch 2101, Training Loss: 0.003505
# Epoch 2101, Test Loss: 0.004359
# Epoch 2201, Training Loss: 0.003284
# Epoch 2201, Test Loss: 0.004103
# Epoch 2301, Training Loss: 0.002848
# Epoch 2301, Test Loss: 0.003604
# Epoch 2401, Training Loss: 0.002242
# Epoch 2401, Test Loss: 0.002903
# Epoch 2501, Training Loss: 0.001954
# Epoch 2501, Test Loss: 0.002651
# Epoch 2601, Training Loss: 0.001876
# Epoch 2601, Test Loss: 0.002594
# Epoch 2701, Training Loss: 0.001838
# Epoch 2701, Test Loss: 0.002548
# Epoch 2801, Training Loss: 0.001812
# Epoch 2801, Test Loss: 0.002503
# Epoch 2901, Training Loss: 0.001791
# Epoch 2901, Test Loss: 0.002466
# Epoch 3001, Training Loss: 0.001774
# Epoch 3001, Test Loss: 0.002440
# Epoch 3101, Training Loss: 0.001766
# Epoch 3101, Test Loss: 0.002396
# Epoch 3201, Training Loss: 0.001745
# Epoch 3201, Test Loss: 0.002387
# Epoch 3301, Training Loss: 0.001733
# Epoch 3301, Test Loss: 0.002367
# Epoch 3401, Training Loss: 0.001721
# Epoch 3401, Test Loss: 0.002345
# Epoch 3501, Training Loss: 0.001710
# Epoch 3501, Test Loss: 0.002334
# Epoch 3601, Training Loss: 0.001699
# Epoch 3601, Test Loss: 0.002319
# Epoch 3701, Training Loss: 0.001687
# Epoch 3701, Test Loss: 0.002308
# Epoch 3801, Training Loss: 0.001675
# Epoch 3801, Test Loss: 0.002303
# Epoch 3901, Training Loss: 0.001662
# Epoch 3901, Test Loss: 0.002284
# Epoch 4001, Training Loss: 0.001647
# Epoch 4001, Test Loss: 0.002263
# Epoch 4101, Training Loss: 0.001624
# Epoch 4101, Test Loss: 0.002252
# Epoch 4201, Training Loss: 0.001596
# Epoch 4201, Test Loss: 0.002220
# Epoch 4301, Training Loss: 0.001555
# Epoch 4301, Test Loss: 0.002183
# Epoch 4401, Training Loss: 0.001496
# Epoch 4401, Test Loss: 0.002108
# Epoch 4501, Training Loss: 0.001404
# Epoch 4501, Test Loss: 0.001997
# Epoch 4601, Training Loss: 0.001268
# Epoch 4601, Test Loss: 0.001800
# Epoch 4701, Training Loss: 0.001087
# Epoch 4701, Test Loss: 0.001531
# Epoch 4801, Training Loss: 0.000927
# Epoch 4801, Test Loss: 0.001278
# Epoch 4901, Training Loss: 0.000837
# Epoch 4901, Test Loss: 0.001124
# Epoch 5001, Training Loss: 0.000797
# Epoch 5001, Test Loss: 0.001035
# Epoch 5101, Training Loss: 0.000817
# Epoch 5101, Test Loss: 0.000997
# Epoch 5201, Training Loss: 0.000763
# Epoch 5201, Test Loss: 0.000957
# Epoch 5301, Training Loss: 0.000754
# Epoch 5301, Test Loss: 0.000936
# Epoch 5401, Training Loss: 0.000746
# Epoch 5401, Test Loss: 0.000920
# Epoch 5501, Training Loss: 0.000739
# Epoch 5501, Test Loss: 0.000906
# Epoch 5601, Training Loss: 0.000734
# Epoch 5601, Test Loss: 0.000896
# Epoch 5701, Training Loss: 0.000772
# Epoch 5701, Test Loss: 0.000900
# Epoch 5801, Training Loss: 0.000724
# Epoch 5801, Test Loss: 0.000878
# Epoch 5901, Training Loss: 0.000720
# Epoch 5901, Test Loss: 0.000871
# Epoch 6001, Training Loss: 0.000717
# Epoch 6001, Test Loss: 0.000869
# Epoch 6101, Training Loss: 0.000717
# Epoch 6101, Test Loss: 0.000855
# Epoch 6201, Training Loss: 0.000709
# Epoch 6201, Test Loss: 0.000854
# Epoch 6301, Training Loss: 0.000705
# Epoch 6301, Test Loss: 0.000849
# Epoch 6401, Training Loss: 0.000702
# Epoch 6401, Test Loss: 0.000848
# Epoch 6501, Training Loss: 0.000702
# Epoch 6501, Test Loss: 0.000856
# Epoch 6601, Training Loss: 0.000696
# Epoch 6601, Test Loss: 0.000842
# Epoch 6701, Training Loss: 0.000693
# Epoch 6701, Test Loss: 0.000839
# Epoch 6801, Training Loss: 0.000691
# Epoch 6801, Test Loss: 0.000842
# Epoch 6901, Training Loss: 0.000688
# Epoch 6901, Test Loss: 0.000838
# Epoch 7001, Training Loss: 0.000685
# Epoch 7001, Test Loss: 0.000838
# Epoch 7101, Training Loss: 0.000683
# Epoch 7101, Test Loss: 0.000837
# Epoch 7201, Training Loss: 0.000680
# Epoch 7201, Test Loss: 0.000840
# Epoch 7301, Training Loss: 0.000677
# Epoch 7301, Test Loss: 0.000839
# Epoch 7401, Training Loss: 0.000674
# Epoch 7401, Test Loss: 0.000839
# Epoch 7501, Training Loss: 0.000672
# Epoch 7501, Test Loss: 0.000843
# Epoch 7601, Training Loss: 0.000670
# Epoch 7601, Test Loss: 0.000840
# Epoch 7701, Training Loss: 0.000663
# Epoch 7701, Test Loss: 0.000848
# Epoch 7801, Training Loss: 0.000659
# Epoch 7801, Test Loss: 0.000852
# Epoch 7901, Training Loss: 0.000654
# Epoch 7901, Test Loss: 0.000854
# Epoch 8001, Training Loss: 0.000648
# Epoch 8001, Test Loss: 0.000857
# Epoch 8101, Training Loss: 0.000640
# Epoch 8101, Test Loss: 0.000858
# Epoch 8201, Training Loss: 0.000635
# Epoch 8201, Test Loss: 0.000880
# Epoch 8301, Training Loss: 0.000615
# Epoch 8301, Test Loss: 0.000846
# Epoch 8401, Training Loss: 0.000598
# Epoch 8401, Test Loss: 0.000821
# Epoch 8501, Training Loss: 0.000550
# Epoch 8501, Test Loss: 0.000784
# Epoch 8601, Training Loss: 0.000501
# Epoch 8601, Test Loss: 0.000689
# Epoch 8701, Training Loss: 0.000432
# Epoch 8701, Test Loss: 0.000595
# Epoch 8801, Training Loss: 0.000382
# Epoch 8801, Test Loss: 0.000514
# Epoch 8901, Training Loss: 0.000354
# Epoch 8901, Test Loss: 0.000467
# Epoch 9001, Training Loss: 0.000337
# Epoch 9001, Test Loss: 0.000413
# Epoch 9101, Training Loss: 0.000329
# Epoch 9101, Test Loss: 0.000401
# Epoch 9201, Training Loss: 0.000323
# Epoch 9201, Test Loss: 0.000392
# Epoch 9301, Training Loss: 0.000319
# Epoch 9301, Test Loss: 0.000388
# Epoch 9401, Training Loss: 0.000316
# Epoch 9401, Test Loss: 0.000384
# Epoch 9501, Training Loss: 0.000313
# Epoch 9501, Test Loss: 0.000382
# Epoch 9601, Training Loss: 0.000310
# Epoch 9601, Test Loss: 0.000380
# Epoch 9701, Training Loss: 0.000308
# Epoch 9701, Test Loss: 0.000378
# Epoch 9801, Training Loss: 0.000305
# Epoch 9801, Test Loss: 0.000376
# Epoch 9901, Training Loss: 0.000305
# Epoch 9901, Test Loss: 0.000387
# Epoch 10001, Training Loss: 0.000301
# Epoch 10001, Test Loss: 0.000373
# Epoch 10101, Training Loss: 0.000299
# Epoch 10101, Test Loss: 0.000372
# Epoch 10201, Training Loss: 0.000297
# Epoch 10201, Test Loss: 0.000371
# Epoch 10301, Training Loss: 0.000295
# Epoch 10301, Test Loss: 0.000369
# Epoch 10401, Training Loss: 0.000294
# Epoch 10401, Test Loss: 0.000366
# Epoch 10501, Training Loss: 0.000294
# Epoch 10501, Test Loss: 0.000369
# Epoch 10601, Training Loss: 0.000289
# Epoch 10601, Test Loss: 0.000365
# Epoch 10701, Training Loss: 0.000286
# Epoch 10701, Test Loss: 0.000362
# Epoch 10801, Training Loss: 0.000283
# Epoch 10801, Test Loss: 0.000361
# Epoch 10901, Training Loss: 0.000280
# Epoch 10901, Test Loss: 0.000358
# Epoch 11001, Training Loss: 0.000277
# Epoch 11001, Test Loss: 0.000355
# Epoch 11101, Training Loss: 0.000273
# Epoch 11101, Test Loss: 0.000353
# Epoch 11201, Training Loss: 0.000282
# Epoch 11201, Test Loss: 0.000367
# Epoch 11301, Training Loss: 0.000277
# Epoch 11301, Test Loss: 0.000345
# Epoch 11401, Training Loss: 0.000255
# Epoch 11401, Test Loss: 0.000343
# Epoch 11501, Training Loss: 0.000247
# Epoch 11501, Test Loss: 0.000339
# Epoch 11601, Training Loss: 0.000237
# Epoch 11601, Test Loss: 0.000331
# Epoch 11701, Training Loss: 0.000227
# Epoch 11701, Test Loss: 0.000322
# Epoch 11801, Training Loss: 0.000216
# Epoch 11801, Test Loss: 0.000314
# Epoch 11901, Training Loss: 0.000218
# Epoch 11901, Test Loss: 0.000330
# Epoch 12001, Training Loss: 0.000196
# Epoch 12001, Test Loss: 0.000290
# Epoch 12101, Training Loss: 0.000188
# Epoch 12101, Test Loss: 0.000280
# Epoch 12201, Training Loss: 0.000181
# Epoch 12201, Test Loss: 0.000271
# Epoch 12301, Training Loss: 0.000177
# Epoch 12301, Test Loss: 0.000261
# Epoch 12401, Training Loss: 0.000171
# Epoch 12401, Test Loss: 0.000254
# Epoch 12501, Training Loss: 0.000167
# Epoch 12501, Test Loss: 0.000248
# Epoch 12601, Training Loss: 0.000164
# Epoch 12601, Test Loss: 0.000243
# Epoch 12701, Training Loss: 0.000162
# Epoch 12701, Test Loss: 0.000238
# Epoch 12801, Training Loss: 0.000160
# Epoch 12801, Test Loss: 0.000234
# Epoch 12901, Training Loss: 0.000158
# Epoch 12901, Test Loss: 0.000230
# Epoch 13001, Training Loss: 0.000156
# Epoch 13001, Test Loss: 0.000227
# Epoch 13101, Training Loss: 0.000155
# Epoch 13101, Test Loss: 0.000224
# Epoch 13201, Training Loss: 0.000157
# Epoch 13201, Test Loss: 0.000221
# Epoch 13301, Training Loss: 0.000153
# Epoch 13301, Test Loss: 0.000219
# Epoch 13401, Training Loss: 0.000152
# Epoch 13401, Test Loss: 0.000217
# Epoch 13501, Training Loss: 0.000151
# Epoch 13501, Test Loss: 0.000214
# Epoch 13601, Training Loss: 0.000150
# Epoch 13601, Test Loss: 0.000212
# Epoch 13701, Training Loss: 0.000149
# Epoch 13701, Test Loss: 0.000210
# Epoch 13801, Training Loss: 0.000148
# Epoch 13801, Test Loss: 0.000209
# Epoch 13901, Training Loss: 0.000148
# Epoch 13901, Test Loss: 0.000209
# Epoch 14001, Training Loss: 0.000147
# Epoch 14001, Test Loss: 0.000208
# Epoch 14101, Training Loss: 0.000147
# Epoch 14101, Test Loss: 0.000205
# Epoch 14201, Training Loss: 0.000147
# Epoch 14201, Test Loss: 0.000205
# Epoch 14301, Training Loss: 0.000145
# Epoch 14301, Test Loss: 0.000202
# Epoch 14401, Training Loss: 0.000145
# Epoch 14401, Test Loss: 0.000201
# Epoch 14501, Training Loss: 0.000144
# Epoch 14501, Test Loss: 0.000200
# Epoch 14601, Training Loss: 0.000144
# Epoch 14601, Test Loss: 0.000199
# Epoch 14701, Training Loss: 0.000147
# Epoch 14701, Test Loss: 0.000201
# Epoch 14801, Training Loss: 0.000143
# Epoch 14801, Test Loss: 0.000197
# Epoch 14901, Training Loss: 0.000142
# Epoch 14901, Test Loss: 0.000196
# Epoch 15001, Training Loss: 0.000142
# Epoch 15001, Test Loss: 0.000195
# Epoch 15101, Training Loss: 0.000142
# Epoch 15101, Test Loss: 0.000195
# Epoch 15201, Training Loss: 0.000141
# Epoch 15201, Test Loss: 0.000194
# Epoch 15301, Training Loss: 0.000141
# Epoch 15301, Test Loss: 0.000193
# Epoch 15401, Training Loss: 0.000140
# Epoch 15401, Test Loss: 0.000193
# Epoch 15501, Training Loss: 0.000140
# Epoch 15501, Test Loss: 0.000193
# Epoch 15601, Training Loss: 0.000140
# Epoch 15601, Test Loss: 0.000192
# Epoch 15701, Training Loss: 0.000139
# Epoch 15701, Test Loss: 0.000191
# Epoch 15801, Training Loss: 0.000141
# Epoch 15801, Test Loss: 0.000194
# Epoch 15901, Training Loss: 0.000139
# Epoch 15901, Test Loss: 0.000191
# Epoch 16001, Training Loss: 0.000139
# Epoch 16001, Test Loss: 0.000191
# Epoch 16101, Training Loss: 0.000138
# Epoch 16101, Test Loss: 0.000190
# Epoch 16201, Training Loss: 0.000138
# Epoch 16201, Test Loss: 0.000190
# Epoch 16301, Training Loss: 0.000138
# Epoch 16301, Test Loss: 0.000190
# Epoch 16401, Training Loss: 0.000138
# Epoch 16401, Test Loss: 0.000190
# Epoch 16501, Training Loss: 0.000137
# Epoch 16501, Test Loss: 0.000189
# Epoch 16601, Training Loss: 0.000144
# Epoch 16601, Test Loss: 0.000195
# Epoch 16701, Training Loss: 0.000137
# Epoch 16701, Test Loss: 0.000190
# Epoch 16801, Training Loss: 0.000136
# Epoch 16801, Test Loss: 0.000189
# Epoch 16901, Training Loss: 0.000136
# Epoch 16901, Test Loss: 0.000188
# Epoch 17001, Training Loss: 0.000138
# Epoch 17001, Test Loss: 0.000190
# Epoch 17101, Training Loss: 0.000136
# Epoch 17101, Test Loss: 0.000188
# Epoch 17201, Training Loss: 0.000145
# Epoch 17201, Test Loss: 0.000191
# Epoch 17301, Training Loss: 0.000135
# Epoch 17301, Test Loss: 0.000187
# Epoch 17401, Training Loss: 0.000135
# Epoch 17401, Test Loss: 0.000188
# Epoch 17501, Training Loss: 0.000156
# Epoch 17501, Test Loss: 0.000205
# Epoch 17601, Training Loss: 0.000140
# Epoch 17601, Test Loss: 0.000189
# Epoch 17701, Training Loss: 0.000134
# Epoch 17701, Test Loss: 0.000187
# Epoch 17801, Training Loss: 0.000135
# Epoch 17801, Test Loss: 0.000187
# Epoch 17901, Training Loss: 0.000134
# Epoch 17901, Test Loss: 0.000188
# Epoch 18001, Training Loss: 0.000133
# Epoch 18001, Test Loss: 0.000187
# Epoch 18101, Training Loss: 0.000135
# Epoch 18101, Test Loss: 0.000187
# Epoch 18201, Training Loss: 0.000133
# Epoch 18201, Test Loss: 0.000189
# Epoch 18301, Training Loss: 0.000133
# Epoch 18301, Test Loss: 0.000188
# Epoch 18401, Training Loss: 0.000133
# Epoch 18401, Test Loss: 0.000187
# Epoch 18501, Training Loss: 0.000133
# Epoch 18501, Test Loss: 0.000188
# Epoch 18601, Training Loss: 0.000132
# Epoch 18601, Test Loss: 0.000187
# Epoch 18701, Training Loss: 0.000133
# Epoch 18701, Test Loss: 0.000189
# Epoch 18801, Training Loss: 0.000132
# Epoch 18801, Test Loss: 0.000187
# Epoch 18901, Training Loss: 0.000137
# Epoch 18901, Test Loss: 0.000189
# Epoch 19001, Training Loss: 0.000137
# Epoch 19001, Test Loss: 0.000196
# Epoch 19101, Training Loss: 0.000131
# Epoch 19101, Test Loss: 0.000187
# Epoch 19201, Training Loss: 0.000131
# Epoch 19201, Test Loss: 0.000187
# Epoch 19301, Training Loss: 0.000131
# Epoch 19301, Test Loss: 0.000187
# Epoch 19401, Training Loss: 0.000131
# Epoch 19401, Test Loss: 0.000188
# Epoch 19501, Training Loss: 0.000130
# Epoch 19501, Test Loss: 0.000187
# Epoch 19601, Training Loss: 0.000131
# Epoch 19601, Test Loss: 0.000187
# Epoch 19701, Training Loss: 0.000130
# Epoch 19701, Test Loss: 0.000187
# Epoch 19801, Training Loss: 0.000131
# Epoch 19801, Test Loss: 0.000191
# Epoch 19901, Training Loss: 0.000134
# Epoch 19901, Test Loss: 0.000189

# %% [markdown]
# # Plotting

# %%
# Losses
plt.semilogy(np.arange(epochs), train_loss_list, color='r', label='Train loss')
plt.semilogy(np.arange(epochs), test_loss_list, color='b', label='Test loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# L2 errors
plt.semilogy(np.arange(epochs), train_err_list, color='r', label='Train error')
plt.semilogy(np.arange(epochs), test_err_list, color='b', label='Test error')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# # Predictions

# %%
x_trial = torch.linspace(0, 1, 100).requires_grad_(True).to(device)
f = lambda x: 1/(2*np.pi)*torch.sin(2*np.pi*x) # A function f that f(0)=0
u_trial = f(x_trial)
v_trial = torch.autograd.grad(outputs=u_trial, inputs=x_trial, grad_outputs=torch.ones_like(u_trial), create_graph=True)[0]
u_pred = model.forward(v_trial.repeat(100, 1), x_trial.view(-1, 1))

# %%
plt.scatter(np.linspace(0, 1, 100), u_pred.data.cpu().detach().numpy(), s=5, color='r', label='Predicted')
plt.plot(np.linspace(0, 1, 100), f(torch.linspace(0, 1, 100)), color='k', label='Actual')
plt.legend()
plt.xlabel('x')
plt.ylabel('u(x)')
plt.show()

# %%
x_trial = torch.linspace(0, 1, 100).requires_grad_(True).to(device)
f = lambda x: -(x - 0.5)**2 + 0.25
u_trial = f(x_trial)
v_trial = torch.autograd.grad(outputs=u_trial, inputs=x_trial, grad_outputs=torch.ones_like(u_trial), create_graph=True)[0]
u_pred = model.forward(v_trial.repeat(100, 1), x_trial.view(-1, 1))

# %%
plt.scatter(np.linspace(0, 1, 100), u_pred.data.cpu().detach().numpy(), s=5, color='r', label='Predicted')
plt.plot(np.linspace(0, 1, 100), f(torch.linspace(0, 1, 100)), color='k', label='Actual')
plt.legend()
plt.xlabel('x')
plt.ylabel('u(x)')
plt.show()
