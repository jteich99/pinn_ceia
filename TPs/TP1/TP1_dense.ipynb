# %% [markdown]
# # TP1 - Pipeline básico para construcción de modelos PINN

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy import linalg
from scipy.interpolate import griddata
import seaborn as sns
import pandas as pd

torch.manual_seed(0)
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Datasets de puntos de colocación

# %%
# Por enunciado
# Puntos de colocación y de datos
N_PDE = 10000
N_BC = 1000
N_DATA = 10
# Límites
X_LIM = (0, 1)
Y_LIM = (0, 1)

# %%
# Dataset en puntos de colocación
X_pde = torch.rand(N_PDE, 2)
plt.scatter(X_pde[:, 0], X_pde[:, 1], s=3, color='red', label='PDE')

# Dataset en puntos de condición de borde
X_bc_1 = torch.hstack((torch.rand(N_BC//4, 1), torch.zeros(N_BC//4, 1)))    # Borde inferior (y=0)
X_bc_2 = torch.hstack((torch.rand(N_BC//4, 1), torch.ones(N_BC//4, 1)))     # Borde superior (y=1)
X_bc_3 = torch.hstack((torch.zeros(N_BC//4, 1), torch.rand(N_BC//4, 1)))    # Borde izquierdo (x=0)
X_bc_4 = torch.hstack((torch.ones(N_BC//4, 1), torch.rand(N_BC//4, 1)))     # Borde derecho (x=1)
X_bc = torch.vstack((X_bc_1, X_bc_2, X_bc_3, X_bc_4))

y_vel_bc_1 = torch.zeros(N_BC//4, 2)                                        # Velocidad nula
y_vel_bc_2 = torch.hstack((torch.ones(N_BC//4, 1), torch.zeros(N_BC//4, 1)))# Velocidad unitaria en x
y_vel_bc_3 = torch.zeros(N_BC//4, 2)                                        # Velocidad nula
y_vel_bc_4 = torch.zeros(N_BC//4, 2)                                        # Velocidad nula
y_vel_bc = torch.vstack((y_vel_bc_1, y_vel_bc_2, y_vel_bc_3, y_vel_bc_4))

X_bc_p = torch.zeros(1,2)
y_bc_p = torch.zeros(1,1)

plt.scatter(X_bc[:, 0], X_bc[:, 1], s=3, color='blue', label='BC vel')
plt.scatter(X_bc_p[:, 0], X_bc_p[:, 1], s=10, color='black', marker='x', label='BC pressure')

plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
# Veamos como es la estructura de los datos suministrados
pressure_data = loadmat('../data/pressure.mat')
velocity_data = loadmat('../data/velocity.mat')

print(f"Keys de pressure.mat: {pressure_data.keys()}")
print(f"Keys de velocity.mat: {velocity_data.keys()}")
print(f"Shape de pressure.mat: {pressure_data['x'].shape}")
print(f"Shape de velocity.mat: {velocity_data['x'].shape}")
# print(pressure_data['x'].shape)
# print(pressure_data['x'].transpose()[:10])
# print(velocity_data.keys())
# print(velocity_data['x'].shape)

X_data_all = torch.tensor(np.hstack((pressure_data['x'].transpose(), pressure_data['y'].transpose())), dtype=torch.float32)
y_data_all = torch.tensor(np.hstack((pressure_data['p'].transpose(), velocity_data['u'].transpose(),velocity_data['v'].transpose())), dtype=torch.float32)

X_data_df = pd.DataFrame({
    'x': X_data_all[:, 0].numpy(),
    'y': X_data_all[:, 1].numpy(),
})

pred_df = pd.DataFrame({
    'x': X_data_all[:, 0].numpy(),
    'y': X_data_all[:, 1].numpy(),
    'p': y_data_all[:, 0].numpy(),
    'u': y_data_all[:, 1].numpy(),
    'v': y_data_all[:, 2].numpy(),
})

print(pred_df[pred_df['y']>= 1].head())

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
[ax.set_xlim(0,1) for ax in axs]
[ax.set_ylim(0,1) for ax in axs]
[
    ax.imshow(
        griddata(
            # np.column_stack((pred_df['x'], pred_df['y'])),
            X_data_all.numpy(),
            pred_df[col],
            np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100)),
            method='cubic'
        ),
        # pred_df.pivot_table(index='y', columns='x', values=col).values,
        origin='lower',
        extent=(0, 1, 0, 1),
        cmap='jet'
    )
    for ax, col in zip(axs, ['p', 'u', 'v'])
]
fig.colorbar(axs[0].images[0], ax=axs[0], label='p')
fig.colorbar(axs[1].images[0], ax=axs[1], label='u')
fig.colorbar(axs[2].images[0], ax=axs[2], label='v')
plt.show()
# Out:
# Keys de pressure.mat: dict_keys(['__header__', '__version__', '__globals__', 'x', 'y', 'z', 'p'])
# Keys de velocity.mat: dict_keys(['__header__', '__version__', '__globals__', 'x', 'y', 'z', 'u', 'v', 'w'])
# Shape de pressure.mat: (1, 20201)
# Shape de velocity.mat: (1, 20201)
#           x    y         p    u    v
# 10100  0.00  1.0 -4.632520  1.0  0.0
# 10101  0.01  1.0 -0.889585  1.0  0.0
# 10102  0.02  1.0 -0.443777  1.0  0.0
# 10103  0.03  1.0 -0.253398  1.0  0.0
# 10104  0.04  1.0 -0.172256  1.0  0.0

# %%
plt.scatter(X_pde[:, 0], X_pde[:, 1], s=3, color='red', label='PDE')
plt.scatter(X_bc[:, 0], X_bc[:, 1], s=3, color='blue', label='BC vel')
plt.scatter(X_bc_p[:, 0], X_bc_p[:, 1], s=10, color='black', marker='x', label='BC pressure')

idxs_data = torch.randint(0, X_data_all.shape[0], (N_DATA,))
X_data = X_data_all[idxs_data, :]
y_data = y_data_all[idxs_data, :]
plt.scatter(X_data[:, 0], X_data[:, 1], s=10, marker='^', color='green', label='DATA')

plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
class PINN(torch.nn.Module):
    def __init__(self, model_params):
        super(PINN, self).__init__()
        self.hidden_layers = model_params['hidden_layers']
        self.hidden_units = model_params['hidden_units']
        self.activation = model_params['activation']
        self.Re = model_params['Re']
        self.device = model_params['device']

        self.layers = torch.nn.ModuleList(
            [torch.nn.Linear(2, self.hidden_units)] +
            [torch.nn.Linear(self.hidden_units, self.hidden_units) for _ in range(self.hidden_layers - 1)] +
            [torch.nn.Linear(self.hidden_units, 3)]
        )

        self.apply(self.init_weights)

    def init_weights(self, m):
        if type(m) == torch.nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
            g = torch.nn.init.calculate_gain('tanh')
            torch.nn.init.xavier_uniform_(m.weight, gain=g)
            m.bias.data.fill_(0)

    def forward(self, x):
        y = x
        for layer in self.layers[:-1]:
            y = self.activation(layer(y))
        y = self.layers[-1](y)
        return y

    def momentum_conservation(self, x, y):
        p = y[:, 0]
        u = y[:, 1]
        v = y[:, 2]

        p_grad = torch.autograd.grad(p, x, grad_outputs=torch.ones_like(p), create_graph=True)[0]
        p_x, p_y = p_grad[:, 0], p_grad[:, 1]
        u_grad = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), create_graph=True)[0]
        u_x, u_y = u_grad[:, 0], u_grad[:, 1]
        v_grad = torch.autograd.grad(v, x, grad_outputs=torch.ones_like(v), create_graph=True)[0]
        v_x, v_y = v_grad[:, 0], v_grad[:, 1]
        u_xx = torch.autograd.grad(u_x, x, grad_outputs=torch.ones_like(u_x), create_graph=True)[0][:, 0]
        u_yy = torch.autograd.grad(u_y, x, grad_outputs=torch.ones_like(u_y), create_graph=True)[0][:, 1]
        v_xx = torch.autograd.grad(v_x, x, grad_outputs=torch.ones_like(v_x), create_graph=True)[0][:, 0]
        v_yy = torch.autograd.grad(v_y, x, grad_outputs=torch.ones_like(v_y), create_graph=True)[0][:, 1]

        # momentum equations (Navier-Stokes) for incompressible flow
        residue_x = u * u_x + v * u_y + p_x - (1/self.Re) * (u_xx + u_yy)
        residue_y = u * v_x + v * v_y + p_y - (1/self.Re) * (v_xx + v_yy)
        return residue_x, residue_y 

    def continuity_equation(self, x, y):
        u = y[:, 1]
        v = y[:, 2]

        u_x = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), create_graph=True)[0][:, 0]
        v_y = torch.autograd.grad(v, x, grad_outputs=torch.ones_like(v), create_graph=True)[0][:, 1]

        return u_x + v_y

# %%
USE_DATA = False
# USE_DATA = True
EPOCHS = 6000
HIDDEN_LAYERS = 4
HIDDEN_UNITS = 64
ACTIVATION = torch.nn.Tanh()

# %%
model_params = {
    'hidden_layers': HIDDEN_LAYERS,
    'hidden_units': HIDDEN_UNITS,
    'activation': ACTIVATION,
    'Re': 100,
    'device': device
}

tags = ['PDE', 'BC_VEL', 'BC_P', 'DATA']
dataset = [
    torch.utils.data.TensorDataset(X_pde, torch.zeros(N_PDE, 1)),   # PDE
    torch.utils.data.TensorDataset(X_bc, y_vel_bc),                 # BC velocity
    torch.utils.data.TensorDataset(X_bc_p, y_bc_p),                 # BC pressure
    torch.utils.data.TensorDataset(X_data, y_data)                 # DATA
]

pinn = PINN(model_params).to(device)

# %%
loss = torch.nn.MSELoss()
# opt = torch.optim.Adam(pinn.parameters(), lr=1e-3)
opt = torch.optim.LBFGS(
    pinn.parameters(), max_iter = 20,
    lr=1e-3, 
    tolerance_grad=1e-09, tolerance_change=1e-11, 
    history_size=50, line_search_fn="strong_wolfe"
)
epoch = 0


loss_history = []
pde_loss_history = []
bc_vel_loss_history = []
bc_p_loss_history = []
data_loss_history = []
l2_error = []
y_pred_hist = []
# for epoch in range(EPOCHS):
while epoch < EPOCHS:
    losses = {}
    def closure():
        opt.zero_grad()
        epoch_loss = []
        for tag in tags:
            if tag == 'PDE':
                X, y = dataset[0][:]
                X, y = X.to(device), y.to(device)
                X.requires_grad = True
                pred_y = pinn(X)
                residue_x, residue_y = pinn.momentum_conservation(X, pred_y)
                continuity = pinn.continuity_equation(X, pred_y)
                loss_pde = loss(residue_x, torch.zeros_like(residue_x)) + loss(residue_y, torch.zeros_like(residue_y)) + loss(continuity, torch.zeros_like(continuity))
                pde_loss_history.append(loss_pde.item())
                epoch_loss.append(loss_pde)
                losses['PDE'] = loss_pde.item()
            elif tag == 'BC_VEL':
                X, y_vel = dataset[1][:]
                X, y_vel = X.to(device), y_vel.to(device)
                X.requires_grad = True
                y_pred = pinn(X)[:, 1:3]
                loss_bc = loss(y_pred, y_vel)
                bc_vel_loss_history.append(loss_bc.item())
                epoch_loss.append(100 * loss_bc)
                losses['BC_VEL'] = loss_bc.item()
            elif tag == 'BC_P':
                X, y_p = dataset[2][:]
                X, y_p = X.to(device), y_p.to(device)
                X.requires_grad = True
                y_pred = pinn(X)[:, 0:1]
                loss_bc_p = loss(y_pred, y_p)
                bc_p_loss_history.append(loss_bc_p.item())
                epoch_loss.append(100 * loss_bc_p)
                losses['BC_P'] = loss_bc_p.item()
            elif tag == 'DATA' and USE_DATA:
                X, y_data = dataset[3][:]
                X, y_data = X.to(device), y_data.to(device)
                y_pred = pinn(X)
                loss_data = loss(y_pred, y_data)
                data_loss_history.append(loss_data.item())
                epoch_loss.append(loss_data)
                losses['DATA'] = loss_data.item()

        epoch_loss = sum(epoch_loss)
        epoch_loss.backward()
        return epoch_loss

    opt.step(closure)        

    # Calculo la norma-2 del error
    pinn.eval()
    with torch.no_grad():
        y_pred = pinn(torch.tensor(X_data_all, dtype=torch.float64).to(device)).detach().cpu().numpy()
        l2_error.append(linalg.norm(y_data_all.numpy() - y_pred))

    if epoch % 10 == 0:
        print(f'Epoch {epoch}, PDE Loss: {losses["PDE"]:.6f}, BC vel. Loss: {losses["BC_VEL"]:.6f}, BC pres. Loss: {losses["BC_P"]:.6f}, DATA Loss: {losses["DATA"] if USE_DATA else "N/A"}, L2 Error: {l2_error[-1]:.6f}')

    # guardado de y_pred
    if epoch % 500 == 0:
        y_pred_hist.append((epoch, y_pred))

    epoch += 1
# Out:
# /tmp/ipykernel_392916/2164202811.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = pinn(torch.tensor(X_data_all, dtype=torch.float64).to(device)).detach().cpu().numpy()
# Epoch 0, PDE Loss: 1.048494, BC vel. Loss: 0.033896, BC pres. Loss: 0.000109, DATA Loss: N/A, L2 Error: 157.198007
# Epoch 10, PDE Loss: 0.089018, BC vel. Loss: 0.011309, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 31.405259
# Epoch 20, PDE Loss: 0.070317, BC vel. Loss: 0.005559, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 29.048998
# Epoch 30, PDE Loss: 0.082822, BC vel. Loss: 0.004209, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 30.940303
# Epoch 40, PDE Loss: 0.073077, BC vel. Loss: 0.004082, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 30.343655
# Epoch 50, PDE Loss: 0.073053, BC vel. Loss: 0.003843, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 31.459261
# Epoch 60, PDE Loss: 0.089354, BC vel. Loss: 0.003355, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 30.799396
# Epoch 70, PDE Loss: 0.092461, BC vel. Loss: 0.002930, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 28.519879
# Epoch 80, PDE Loss: 0.080809, BC vel. Loss: 0.002732, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 27.415920
# Epoch 90, PDE Loss: 0.074783, BC vel. Loss: 0.002648, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 27.821207
# Epoch 100, PDE Loss: 0.072449, BC vel. Loss: 0.002508, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 26.755309
# Epoch 110, PDE Loss: 0.074868, BC vel. Loss: 0.002291, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 25.717087
# Epoch 120, PDE Loss: 0.070409, BC vel. Loss: 0.002149, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 25.209526
# Epoch 130, PDE Loss: 0.067855, BC vel. Loss: 0.002024, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 25.783858
# Epoch 140, PDE Loss: 0.066427, BC vel. Loss: 0.001896, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 24.959570
# Epoch 150, PDE Loss: 0.059985, BC vel. Loss: 0.001820, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 25.159204
# Epoch 160, PDE Loss: 0.060738, BC vel. Loss: 0.001677, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 24.434011
# Epoch 170, PDE Loss: 0.060912, BC vel. Loss: 0.001503, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 23.675455
# Epoch 180, PDE Loss: 0.055485, BC vel. Loss: 0.001368, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 23.084642
# Epoch 190, PDE Loss: 0.048526, BC vel. Loss: 0.001213, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 21.044620
# Epoch 200, PDE Loss: 0.037213, BC vel. Loss: 0.001086, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 18.903489
# Epoch 210, PDE Loss: 0.034774, BC vel. Loss: 0.000870, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 18.131444
# Epoch 220, PDE Loss: 0.030590, BC vel. Loss: 0.000710, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 18.269423
# Epoch 230, PDE Loss: 0.025490, BC vel. Loss: 0.000624, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 17.399685
# Epoch 240, PDE Loss: 0.022088, BC vel. Loss: 0.000563, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 15.931181
# Epoch 250, PDE Loss: 0.019462, BC vel. Loss: 0.000519, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 14.553058
# Epoch 260, PDE Loss: 0.015068, BC vel. Loss: 0.000501, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 13.283729
# Epoch 270, PDE Loss: 0.013999, BC vel. Loss: 0.000461, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 12.644634
# Epoch 280, PDE Loss: 0.013209, BC vel. Loss: 0.000432, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 12.373893
# Epoch 290, PDE Loss: 0.012620, BC vel. Loss: 0.000404, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 12.653956
# Epoch 300, PDE Loss: 0.011892, BC vel. Loss: 0.000383, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 12.412438
# Epoch 310, PDE Loss: 0.011135, BC vel. Loss: 0.000366, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 11.478700
# Epoch 320, PDE Loss: 0.010742, BC vel. Loss: 0.000354, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 11.723096
# Epoch 330, PDE Loss: 0.009879, BC vel. Loss: 0.000342, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 11.278948
# Epoch 340, PDE Loss: 0.009690, BC vel. Loss: 0.000327, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.757105
# Epoch 350, PDE Loss: 0.009387, BC vel. Loss: 0.000313, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.926085
# Epoch 360, PDE Loss: 0.009412, BC vel. Loss: 0.000297, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.834876
# Epoch 370, PDE Loss: 0.009092, BC vel. Loss: 0.000287, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 11.091203
# Epoch 380, PDE Loss: 0.008523, BC vel. Loss: 0.000280, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.901532
# Epoch 390, PDE Loss: 0.008378, BC vel. Loss: 0.000269, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.821898
# Epoch 400, PDE Loss: 0.007914, BC vel. Loss: 0.000259, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.698401
# Epoch 410, PDE Loss: 0.007630, BC vel. Loss: 0.000252, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.616667
# Epoch 420, PDE Loss: 0.007674, BC vel. Loss: 0.000240, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.436882
# Epoch 430, PDE Loss: 0.007436, BC vel. Loss: 0.000230, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.153023
# Epoch 440, PDE Loss: 0.007454, BC vel. Loss: 0.000219, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 10.106312
# Epoch 450, PDE Loss: 0.006905, BC vel. Loss: 0.000214, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.820664
# Epoch 460, PDE Loss: 0.006656, BC vel. Loss: 0.000207, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.438012
# Epoch 470, PDE Loss: 0.006580, BC vel. Loss: 0.000201, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.303090
# Epoch 480, PDE Loss: 0.006485, BC vel. Loss: 0.000196, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.546255
# Epoch 490, PDE Loss: 0.006743, BC vel. Loss: 0.000186, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.565762
# Epoch 500, PDE Loss: 0.006734, BC vel. Loss: 0.000179, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.505140
# Epoch 510, PDE Loss: 0.006779, BC vel. Loss: 0.000171, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.351461
# Epoch 520, PDE Loss: 0.006632, BC vel. Loss: 0.000166, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.292991
# Epoch 530, PDE Loss: 0.006764, BC vel. Loss: 0.000158, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.292292
# Epoch 540, PDE Loss: 0.007005, BC vel. Loss: 0.000150, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.950236
# Epoch 550, PDE Loss: 0.007234, BC vel. Loss: 0.000142, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.886918
# Epoch 560, PDE Loss: 0.007341, BC vel. Loss: 0.000132, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.949829
# Epoch 570, PDE Loss: 0.007291, BC vel. Loss: 0.000121, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.936835
# Epoch 580, PDE Loss: 0.007172, BC vel. Loss: 0.000110, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.123953
# Epoch 590, PDE Loss: 0.006768, BC vel. Loss: 0.000102, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 9.360817
# Epoch 600, PDE Loss: 0.006344, BC vel. Loss: 0.000095, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.953424
# Epoch 610, PDE Loss: 0.006066, BC vel. Loss: 0.000088, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.966235
# Epoch 620, PDE Loss: 0.006076, BC vel. Loss: 0.000080, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.809889
# Epoch 630, PDE Loss: 0.005795, BC vel. Loss: 0.000074, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.677005
# Epoch 640, PDE Loss: 0.005648, BC vel. Loss: 0.000065, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.853457
# Epoch 650, PDE Loss: 0.005487, BC vel. Loss: 0.000061, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.757066
# Epoch 660, PDE Loss: 0.005322, BC vel. Loss: 0.000057, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.756556
# Epoch 670, PDE Loss: 0.005314, BC vel. Loss: 0.000053, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.719705
# Epoch 680, PDE Loss: 0.005243, BC vel. Loss: 0.000050, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.633001
# Epoch 690, PDE Loss: 0.005077, BC vel. Loss: 0.000048, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.465416
# Epoch 700, PDE Loss: 0.004976, BC vel. Loss: 0.000046, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.529303
# Epoch 710, PDE Loss: 0.004851, BC vel. Loss: 0.000045, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.654245
# Epoch 720, PDE Loss: 0.004664, BC vel. Loss: 0.000045, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.697649
# Epoch 730, PDE Loss: 0.004613, BC vel. Loss: 0.000043, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.652203
# Epoch 740, PDE Loss: 0.004632, BC vel. Loss: 0.000041, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.769980
# Epoch 750, PDE Loss: 0.004454, BC vel. Loss: 0.000039, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.831572
# Epoch 760, PDE Loss: 0.004347, BC vel. Loss: 0.000037, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.784197
# Epoch 770, PDE Loss: 0.004245, BC vel. Loss: 0.000035, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.538823
# Epoch 780, PDE Loss: 0.004135, BC vel. Loss: 0.000034, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.567461
# Epoch 790, PDE Loss: 0.004054, BC vel. Loss: 0.000032, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.339285
# Epoch 800, PDE Loss: 0.003865, BC vel. Loss: 0.000032, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.062532
# Epoch 810, PDE Loss: 0.003814, BC vel. Loss: 0.000030, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 8.033723
# Epoch 820, PDE Loss: 0.003779, BC vel. Loss: 0.000028, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.985910
# Epoch 830, PDE Loss: 0.003705, BC vel. Loss: 0.000026, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.830482
# Epoch 840, PDE Loss: 0.003605, BC vel. Loss: 0.000026, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.771790
# Epoch 850, PDE Loss: 0.003600, BC vel. Loss: 0.000024, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.685794
# Epoch 860, PDE Loss: 0.003568, BC vel. Loss: 0.000023, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.553420
# Epoch 870, PDE Loss: 0.003466, BC vel. Loss: 0.000022, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.378638
# Epoch 880, PDE Loss: 0.003414, BC vel. Loss: 0.000021, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 7.181310
# Epoch 890, PDE Loss: 0.003379, BC vel. Loss: 0.000020, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.970512
# Epoch 900, PDE Loss: 0.003299, BC vel. Loss: 0.000019, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.824405
# Epoch 910, PDE Loss: 0.003234, BC vel. Loss: 0.000019, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.731489
# Epoch 920, PDE Loss: 0.003217, BC vel. Loss: 0.000018, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.532500
# Epoch 930, PDE Loss: 0.003172, BC vel. Loss: 0.000018, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.527471
# Epoch 940, PDE Loss: 0.003066, BC vel. Loss: 0.000017, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.460194
# Epoch 950, PDE Loss: 0.003054, BC vel. Loss: 0.000017, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.438642
# Epoch 960, PDE Loss: 0.003011, BC vel. Loss: 0.000016, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.261906
# Epoch 970, PDE Loss: 0.002931, BC vel. Loss: 0.000015, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.223952
# Epoch 980, PDE Loss: 0.002873, BC vel. Loss: 0.000015, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 6.136882
# Epoch 990, PDE Loss: 0.002828, BC vel. Loss: 0.000014, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.994027
# Epoch 1000, PDE Loss: 0.002769, BC vel. Loss: 0.000014, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.834009
# Epoch 1010, PDE Loss: 0.002724, BC vel. Loss: 0.000013, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.780628
# Epoch 1020, PDE Loss: 0.002668, BC vel. Loss: 0.000012, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.829529
# Epoch 1030, PDE Loss: 0.002652, BC vel. Loss: 0.000012, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.857012
# Epoch 1040, PDE Loss: 0.002614, BC vel. Loss: 0.000012, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.818863
# Epoch 1050, PDE Loss: 0.002563, BC vel. Loss: 0.000011, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.831079
# Epoch 1060, PDE Loss: 0.002502, BC vel. Loss: 0.000011, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.780896
# Epoch 1070, PDE Loss: 0.002466, BC vel. Loss: 0.000011, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.764182
# Epoch 1080, PDE Loss: 0.002407, BC vel. Loss: 0.000011, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.703687
# Epoch 1090, PDE Loss: 0.002382, BC vel. Loss: 0.000010, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.656645
# Epoch 1100, PDE Loss: 0.002336, BC vel. Loss: 0.000010, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.512793
# Epoch 1110, PDE Loss: 0.002283, BC vel. Loss: 0.000010, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.476277
# Epoch 1120, PDE Loss: 0.002251, BC vel. Loss: 0.000009, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.389960
# Epoch 1130, PDE Loss: 0.002185, BC vel. Loss: 0.000009, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.338480
# Epoch 1140, PDE Loss: 0.002136, BC vel. Loss: 0.000009, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.364032
# Epoch 1150, PDE Loss: 0.002096, BC vel. Loss: 0.000009, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.280948
# Epoch 1160, PDE Loss: 0.002064, BC vel. Loss: 0.000008, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.237833
# Epoch 1170, PDE Loss: 0.002046, BC vel. Loss: 0.000008, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.187227
# Epoch 1180, PDE Loss: 0.002008, BC vel. Loss: 0.000008, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.083918
# Epoch 1190, PDE Loss: 0.001991, BC vel. Loss: 0.000007, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 5.002856
# Epoch 1200, PDE Loss: 0.001964, BC vel. Loss: 0.000007, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.884316
# Epoch 1210, PDE Loss: 0.001953, BC vel. Loss: 0.000006, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.822151
# Epoch 1220, PDE Loss: 0.001928, BC vel. Loss: 0.000006, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.790710
# Epoch 1230, PDE Loss: 0.001898, BC vel. Loss: 0.000006, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.747897
# Epoch 1240, PDE Loss: 0.001860, BC vel. Loss: 0.000006, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.647280
# Epoch 1250, PDE Loss: 0.001838, BC vel. Loss: 0.000005, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.582284
# Epoch 1260, PDE Loss: 0.001806, BC vel. Loss: 0.000005, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.464464
# Epoch 1270, PDE Loss: 0.001770, BC vel. Loss: 0.000005, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.389280
# Epoch 1280, PDE Loss: 0.001743, BC vel. Loss: 0.000005, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.413532
# Epoch 1290, PDE Loss: 0.001727, BC vel. Loss: 0.000005, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.339133
# Epoch 1300, PDE Loss: 0.001690, BC vel. Loss: 0.000005, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.315882
# Epoch 1310, PDE Loss: 0.001647, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.251988
# Epoch 1320, PDE Loss: 0.001616, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.236503
# Epoch 1330, PDE Loss: 0.001573, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.323889
# Epoch 1340, PDE Loss: 0.001547, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.272756
# Epoch 1350, PDE Loss: 0.001512, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.312422
# Epoch 1360, PDE Loss: 0.001487, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.323997
# Epoch 1370, PDE Loss: 0.001467, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.356400
# Epoch 1380, PDE Loss: 0.001437, BC vel. Loss: 0.000004, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.347593
# Epoch 1390, PDE Loss: 0.001425, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.425257
# Epoch 1400, PDE Loss: 0.001408, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.483984
# Epoch 1410, PDE Loss: 0.001387, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.477231
# Epoch 1420, PDE Loss: 0.001371, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.416849
# Epoch 1430, PDE Loss: 0.001351, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.411758
# Epoch 1440, PDE Loss: 0.001329, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.353021
# Epoch 1450, PDE Loss: 0.001307, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.295298
# Epoch 1460, PDE Loss: 0.001285, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.253356
# Epoch 1470, PDE Loss: 0.001275, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.242915
# Epoch 1480, PDE Loss: 0.001254, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.231866
# Epoch 1490, PDE Loss: 0.001243, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.239292
# Epoch 1500, PDE Loss: 0.001235, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.218063
# Epoch 1510, PDE Loss: 0.001215, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.205523
# Epoch 1520, PDE Loss: 0.001202, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.199151
# Epoch 1530, PDE Loss: 0.001191, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.197537
# Epoch 1540, PDE Loss: 0.001182, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.186017
# Epoch 1550, PDE Loss: 0.001165, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.135391
# Epoch 1560, PDE Loss: 0.001146, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.120094
# Epoch 1570, PDE Loss: 0.001132, BC vel. Loss: 0.000003, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.094421
# Epoch 1580, PDE Loss: 0.001123, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.094076
# Epoch 1590, PDE Loss: 0.001111, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.094344
# Epoch 1600, PDE Loss: 0.001097, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.098503
# Epoch 1610, PDE Loss: 0.001083, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.089491
# Epoch 1620, PDE Loss: 0.001076, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.112203
# Epoch 1630, PDE Loss: 0.001064, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.132070
# Epoch 1640, PDE Loss: 0.001046, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.088523
# Epoch 1650, PDE Loss: 0.001036, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.101767
# Epoch 1660, PDE Loss: 0.001029, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.090811
# Epoch 1670, PDE Loss: 0.001023, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.066526
# Epoch 1680, PDE Loss: 0.001011, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.054212
# Epoch 1690, PDE Loss: 0.000997, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.029763
# Epoch 1700, PDE Loss: 0.000988, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.005300
# Epoch 1710, PDE Loss: 0.000981, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.001371
# Epoch 1720, PDE Loss: 0.000976, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.001472
# Epoch 1730, PDE Loss: 0.000969, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.985023
# Epoch 1740, PDE Loss: 0.000956, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.991932
# Epoch 1750, PDE Loss: 0.000947, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.998545
# Epoch 1760, PDE Loss: 0.000935, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.001926
# Epoch 1770, PDE Loss: 0.000923, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.990317
# Epoch 1780, PDE Loss: 0.000911, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.000630
# Epoch 1790, PDE Loss: 0.000908, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.034304
# Epoch 1800, PDE Loss: 0.000898, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.052665
# Epoch 1810, PDE Loss: 0.000889, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.035018
# Epoch 1820, PDE Loss: 0.000880, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 4.012623
# Epoch 1830, PDE Loss: 0.000868, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.977751
# Epoch 1840, PDE Loss: 0.000858, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.951256
# Epoch 1850, PDE Loss: 0.000852, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.936429
# Epoch 1860, PDE Loss: 0.000844, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.906483
# Epoch 1870, PDE Loss: 0.000837, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.878477
# Epoch 1880, PDE Loss: 0.000828, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.866981
# Epoch 1890, PDE Loss: 0.000821, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.871163
# Epoch 1900, PDE Loss: 0.000815, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.886007
# Epoch 1910, PDE Loss: 0.000809, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.887666
# Epoch 1920, PDE Loss: 0.000802, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.934118
# Epoch 1930, PDE Loss: 0.000791, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.931851
# Epoch 1940, PDE Loss: 0.000781, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.936144
# Epoch 1950, PDE Loss: 0.000776, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.940067
# Epoch 1960, PDE Loss: 0.000769, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.922426
# Epoch 1970, PDE Loss: 0.000759, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.888898
# Epoch 1980, PDE Loss: 0.000755, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.881226
# Epoch 1990, PDE Loss: 0.000748, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.856343
# Epoch 2000, PDE Loss: 0.000743, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.842908
# Epoch 2010, PDE Loss: 0.000740, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.856454
# Epoch 2020, PDE Loss: 0.000736, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.868624
# Epoch 2030, PDE Loss: 0.000732, BC vel. Loss: 0.000002, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.886280
# Epoch 2040, PDE Loss: 0.000728, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.895326
# Epoch 2050, PDE Loss: 0.000720, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.883115
# Epoch 2060, PDE Loss: 0.000714, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.885921
# Epoch 2070, PDE Loss: 0.000709, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.887864
# Epoch 2080, PDE Loss: 0.000703, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.876219
# Epoch 2090, PDE Loss: 0.000696, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.878560
# Epoch 2100, PDE Loss: 0.000693, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.878618
# Epoch 2110, PDE Loss: 0.000686, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.872812
# Epoch 2120, PDE Loss: 0.000682, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.855893
# Epoch 2130, PDE Loss: 0.000676, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.849424
# Epoch 2140, PDE Loss: 0.000672, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.847914
# Epoch 2150, PDE Loss: 0.000666, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.824703
# Epoch 2160, PDE Loss: 0.000663, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.818391
# Epoch 2170, PDE Loss: 0.000659, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.806791
# Epoch 2180, PDE Loss: 0.000655, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.794965
# Epoch 2190, PDE Loss: 0.000649, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.776952
# Epoch 2200, PDE Loss: 0.000644, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.770784
# Epoch 2210, PDE Loss: 0.000641, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.752201
# Epoch 2220, PDE Loss: 0.000637, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.737048
# Epoch 2230, PDE Loss: 0.000631, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.735596
# Epoch 2240, PDE Loss: 0.000627, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.729452
# Epoch 2250, PDE Loss: 0.000624, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.736542
# Epoch 2260, PDE Loss: 0.000618, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.745319
# Epoch 2270, PDE Loss: 0.000614, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.735886
# Epoch 2280, PDE Loss: 0.000610, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.741540
# Epoch 2290, PDE Loss: 0.000608, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.750306
# Epoch 2300, PDE Loss: 0.000604, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.752085
# Epoch 2310, PDE Loss: 0.000598, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.747851
# Epoch 2320, PDE Loss: 0.000595, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.731443
# Epoch 2330, PDE Loss: 0.000590, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.731676
# Epoch 2340, PDE Loss: 0.000586, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.737325
# Epoch 2350, PDE Loss: 0.000581, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.736446
# Epoch 2360, PDE Loss: 0.000574, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.743760
# Epoch 2370, PDE Loss: 0.000570, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.754597
# Epoch 2380, PDE Loss: 0.000566, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.749207
# Epoch 2390, PDE Loss: 0.000561, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.760238
# Epoch 2400, PDE Loss: 0.000556, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.752412
# Epoch 2410, PDE Loss: 0.000553, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.741983
# Epoch 2420, PDE Loss: 0.000548, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.732985
# Epoch 2430, PDE Loss: 0.000545, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.723893
# Epoch 2440, PDE Loss: 0.000540, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.704171
# Epoch 2450, PDE Loss: 0.000535, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.694395
# Epoch 2460, PDE Loss: 0.000530, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.682497
# Epoch 2470, PDE Loss: 0.000524, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.656932
# Epoch 2480, PDE Loss: 0.000520, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.643061
# Epoch 2490, PDE Loss: 0.000516, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.648044
# Epoch 2500, PDE Loss: 0.000513, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.658569
# Epoch 2510, PDE Loss: 0.000511, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.659480
# Epoch 2520, PDE Loss: 0.000508, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.659215
# Epoch 2530, PDE Loss: 0.000505, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.675944
# Epoch 2540, PDE Loss: 0.000504, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.688044
# Epoch 2550, PDE Loss: 0.000502, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.689029
# Epoch 2560, PDE Loss: 0.000501, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.704267
# Epoch 2570, PDE Loss: 0.000497, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.705009
# Epoch 2580, PDE Loss: 0.000493, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.712513
# Epoch 2590, PDE Loss: 0.000489, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.714215
# Epoch 2600, PDE Loss: 0.000487, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.709988
# Epoch 2610, PDE Loss: 0.000484, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.717732
# Epoch 2620, PDE Loss: 0.000481, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.718332
# Epoch 2630, PDE Loss: 0.000479, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.712438
# Epoch 2640, PDE Loss: 0.000475, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.708863
# Epoch 2650, PDE Loss: 0.000473, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.716498
# Epoch 2660, PDE Loss: 0.000471, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.724304
# Epoch 2670, PDE Loss: 0.000470, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.722274
# Epoch 2680, PDE Loss: 0.000468, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.712135
# Epoch 2690, PDE Loss: 0.000464, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.711299
# Epoch 2700, PDE Loss: 0.000460, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.706546
# Epoch 2710, PDE Loss: 0.000457, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.700575
# Epoch 2720, PDE Loss: 0.000455, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.694637
# Epoch 2730, PDE Loss: 0.000451, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.692992
# Epoch 2740, PDE Loss: 0.000447, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.691706
# Epoch 2750, PDE Loss: 0.000444, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.699252
# Epoch 2760, PDE Loss: 0.000441, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.694520
# Epoch 2770, PDE Loss: 0.000439, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.702445
# Epoch 2780, PDE Loss: 0.000438, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.711155
# Epoch 2790, PDE Loss: 0.000435, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.712700
# Epoch 2800, PDE Loss: 0.000433, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.719444
# Epoch 2810, PDE Loss: 0.000431, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.716987
# Epoch 2820, PDE Loss: 0.000430, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.716965
# Epoch 2830, PDE Loss: 0.000428, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.723410
# Epoch 2840, PDE Loss: 0.000427, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.727443
# Epoch 2850, PDE Loss: 0.000426, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.728107
# Epoch 2860, PDE Loss: 0.000425, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.728182
# Epoch 2870, PDE Loss: 0.000423, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.725688
# Epoch 2880, PDE Loss: 0.000420, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.728064
# Epoch 2890, PDE Loss: 0.000419, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.722867
# Epoch 2900, PDE Loss: 0.000417, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.714665
# Epoch 2910, PDE Loss: 0.000416, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.712499
# Epoch 2920, PDE Loss: 0.000415, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.726365
# Epoch 2930, PDE Loss: 0.000412, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.719190
# Epoch 2940, PDE Loss: 0.000409, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.711488
# Epoch 2950, PDE Loss: 0.000406, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.706151
# Epoch 2960, PDE Loss: 0.000404, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.696824
# Epoch 2970, PDE Loss: 0.000403, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.685949
# Epoch 2980, PDE Loss: 0.000401, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.677553
# Epoch 2990, PDE Loss: 0.000400, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.667366
# Epoch 3000, PDE Loss: 0.000396, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.642430
# Epoch 3010, PDE Loss: 0.000393, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.620925
# Epoch 3020, PDE Loss: 0.000391, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.610574
# Epoch 3030, PDE Loss: 0.000389, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.607398
# Epoch 3040, PDE Loss: 0.000386, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.604566
# Epoch 3050, PDE Loss: 0.000384, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.595282
# Epoch 3060, PDE Loss: 0.000382, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.590669
# Epoch 3070, PDE Loss: 0.000381, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.594227
# Epoch 3080, PDE Loss: 0.000379, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.593960
# Epoch 3090, PDE Loss: 0.000377, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.588202
# Epoch 3100, PDE Loss: 0.000375, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.586464
# Epoch 3110, PDE Loss: 0.000374, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.591466
# Epoch 3120, PDE Loss: 0.000372, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.593796
# Epoch 3130, PDE Loss: 0.000371, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.597669
# Epoch 3140, PDE Loss: 0.000370, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.596792
# Epoch 3150, PDE Loss: 0.000368, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.584542
# Epoch 3160, PDE Loss: 0.000367, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.583956
# Epoch 3170, PDE Loss: 0.000365, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.581231
# Epoch 3180, PDE Loss: 0.000364, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.570202
# Epoch 3190, PDE Loss: 0.000363, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.558884
# Epoch 3200, PDE Loss: 0.000361, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.557302
# Epoch 3210, PDE Loss: 0.000360, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.553419
# Epoch 3220, PDE Loss: 0.000358, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.549013
# Epoch 3230, PDE Loss: 0.000355, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.539652
# Epoch 3240, PDE Loss: 0.000352, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.522971
# Epoch 3250, PDE Loss: 0.000351, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.510314
# Epoch 3260, PDE Loss: 0.000349, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.501447
# Epoch 3270, PDE Loss: 0.000347, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.496301
# Epoch 3280, PDE Loss: 0.000345, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.494311
# Epoch 3290, PDE Loss: 0.000344, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.492908
# Epoch 3300, PDE Loss: 0.000341, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.482468
# Epoch 3310, PDE Loss: 0.000339, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.487917
# Epoch 3320, PDE Loss: 0.000337, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.477761
# Epoch 3330, PDE Loss: 0.000336, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.477958
# Epoch 3340, PDE Loss: 0.000335, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.472710
# Epoch 3350, PDE Loss: 0.000334, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.466931
# Epoch 3360, PDE Loss: 0.000333, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.468641
# Epoch 3370, PDE Loss: 0.000331, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.463900
# Epoch 3380, PDE Loss: 0.000329, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.456742
# Epoch 3390, PDE Loss: 0.000328, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.448998
# Epoch 3400, PDE Loss: 0.000326, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.452934
# Epoch 3410, PDE Loss: 0.000326, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.450249
# Epoch 3420, PDE Loss: 0.000324, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.443123
# Epoch 3430, PDE Loss: 0.000322, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.433943
# Epoch 3440, PDE Loss: 0.000321, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.426217
# Epoch 3450, PDE Loss: 0.000320, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.418778
# Epoch 3460, PDE Loss: 0.000318, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.412366
# Epoch 3470, PDE Loss: 0.000318, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.412257
# Epoch 3480, PDE Loss: 0.000316, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.413558
# Epoch 3490, PDE Loss: 0.000315, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.409005
# Epoch 3500, PDE Loss: 0.000315, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.402388
# Epoch 3510, PDE Loss: 0.000314, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.393206
# Epoch 3520, PDE Loss: 0.000312, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.383671
# Epoch 3530, PDE Loss: 0.000311, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.383174
# Epoch 3540, PDE Loss: 0.000310, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.384082
# Epoch 3550, PDE Loss: 0.000308, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.381024
# Epoch 3560, PDE Loss: 0.000307, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.381463
# Epoch 3570, PDE Loss: 0.000306, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.381853
# Epoch 3580, PDE Loss: 0.000304, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.380969
# Epoch 3590, PDE Loss: 0.000304, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.383305
# Epoch 3600, PDE Loss: 0.000302, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.380850
# Epoch 3610, PDE Loss: 0.000301, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.379230
# Epoch 3620, PDE Loss: 0.000299, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.372873
# Epoch 3630, PDE Loss: 0.000297, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.367711
# Epoch 3640, PDE Loss: 0.000296, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.364557
# Epoch 3650, PDE Loss: 0.000294, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.359984
# Epoch 3660, PDE Loss: 0.000292, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.353413
# Epoch 3670, PDE Loss: 0.000291, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.347366
# Epoch 3680, PDE Loss: 0.000290, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.340769
# Epoch 3690, PDE Loss: 0.000289, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.341681
# Epoch 3700, PDE Loss: 0.000287, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.337529
# Epoch 3710, PDE Loss: 0.000285, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.339774
# Epoch 3720, PDE Loss: 0.000283, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.342874
# Epoch 3730, PDE Loss: 0.000280, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.342582
# Epoch 3740, PDE Loss: 0.000279, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.343536
# Epoch 3750, PDE Loss: 0.000277, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.342286
# Epoch 3760, PDE Loss: 0.000275, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.341320
# Epoch 3770, PDE Loss: 0.000274, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.341740
# Epoch 3780, PDE Loss: 0.000273, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.349609
# Epoch 3790, PDE Loss: 0.000272, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.356395
# Epoch 3800, PDE Loss: 0.000270, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.362849
# Epoch 3810, PDE Loss: 0.000269, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.366461
# Epoch 3820, PDE Loss: 0.000269, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.368510
# Epoch 3830, PDE Loss: 0.000267, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.370530
# Epoch 3840, PDE Loss: 0.000266, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.362604
# Epoch 3850, PDE Loss: 0.000265, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.363889
# Epoch 3860, PDE Loss: 0.000264, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.364622
# Epoch 3870, PDE Loss: 0.000263, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.368340
# Epoch 3880, PDE Loss: 0.000263, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.370431
# Epoch 3890, PDE Loss: 0.000261, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.367531
# Epoch 3900, PDE Loss: 0.000260, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.368685
# Epoch 3910, PDE Loss: 0.000258, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.367587
# Epoch 3920, PDE Loss: 0.000258, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.369230
# Epoch 3930, PDE Loss: 0.000258, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.378319
# Epoch 3940, PDE Loss: 0.000257, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.382599
# Epoch 3950, PDE Loss: 0.000257, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.385577
# Epoch 3960, PDE Loss: 0.000256, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.384115
# Epoch 3970, PDE Loss: 0.000256, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.391051
# Epoch 3980, PDE Loss: 0.000255, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.393844
# Epoch 3990, PDE Loss: 0.000255, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.396985
# Epoch 4000, PDE Loss: 0.000254, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.393525
# Epoch 4010, PDE Loss: 0.000254, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.393328
# Epoch 4020, PDE Loss: 0.000253, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.395046
# Epoch 4030, PDE Loss: 0.000252, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.395227
# Epoch 4040, PDE Loss: 0.000252, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.398238
# Epoch 4050, PDE Loss: 0.000251, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.400260
# Epoch 4060, PDE Loss: 0.000250, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.397143
# Epoch 4070, PDE Loss: 0.000250, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.396754
# Epoch 4080, PDE Loss: 0.000249, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.398775
# Epoch 4090, PDE Loss: 0.000249, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.398722
# Epoch 4100, PDE Loss: 0.000248, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.400323
# ...
# Epoch 4630, PDE Loss: 0.000204, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.341421
# Epoch 4640, PDE Loss: 0.000203, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.342735
# Epoch 4650, PDE Loss: 0.000202, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.346006
# Epoch 4660, PDE Loss: 0.000201, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.336934
# Epoch 4670, PDE Loss: 0.000201, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.336765
# Epoch 4680, PDE Loss: 0.000200, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.333722
# Epoch 4690, PDE Loss: 0.000199, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329561
# Epoch 4700, PDE Loss: 0.000198, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.326062
# Epoch 4710, PDE Loss: 0.000198, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325777
# Epoch 4720, PDE Loss: 0.000198, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.324902
# Epoch 4730, PDE Loss: 0.000197, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329365
# Epoch 4740, PDE Loss: 0.000197, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.333347
# Epoch 4750, PDE Loss: 0.000196, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.331101
# Epoch 4760, PDE Loss: 0.000196, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.331734
# Epoch 4770, PDE Loss: 0.000196, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.334880
# Epoch 4780, PDE Loss: 0.000195, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.335470
# Epoch 4790, PDE Loss: 0.000194, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.334431
# Epoch 4800, PDE Loss: 0.000193, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.326258
# Epoch 4810, PDE Loss: 0.000191, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.323261
# Epoch 4820, PDE Loss: 0.000190, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317371
# Epoch 4830, PDE Loss: 0.000189, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.309282
# Epoch 4840, PDE Loss: 0.000188, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.308140
# Epoch 4850, PDE Loss: 0.000188, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.307160
# Epoch 4860, PDE Loss: 0.000187, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.306602
# Epoch 4870, PDE Loss: 0.000186, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.312549
# Epoch 4880, PDE Loss: 0.000186, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.309298
# Epoch 4890, PDE Loss: 0.000185, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.311516
# Epoch 4900, PDE Loss: 0.000185, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317149
# Epoch 4910, PDE Loss: 0.000185, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.318104
# Epoch 4920, PDE Loss: 0.000185, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.318432
# Epoch 4930, PDE Loss: 0.000184, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.322355
# Epoch 4940, PDE Loss: 0.000184, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.322166
# Epoch 4950, PDE Loss: 0.000184, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.319610
# Epoch 4960, PDE Loss: 0.000184, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.324855
# Epoch 4970, PDE Loss: 0.000183, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325249
# Epoch 4980, PDE Loss: 0.000183, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.323732
# Epoch 4990, PDE Loss: 0.000182, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.318842
# Epoch 5000, PDE Loss: 0.000181, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.312916
# Epoch 5010, PDE Loss: 0.000181, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.310637
# Epoch 5020, PDE Loss: 0.000180, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.306034
# Epoch 5030, PDE Loss: 0.000179, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.300211
# Epoch 5040, PDE Loss: 0.000179, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.296974
# Epoch 5050, PDE Loss: 0.000178, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.296552
# Epoch 5060, PDE Loss: 0.000178, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.296982
# Epoch 5070, PDE Loss: 0.000177, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.300061
# Epoch 5080, PDE Loss: 0.000177, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.300244
# Epoch 5090, PDE Loss: 0.000176, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.300899
# Epoch 5100, PDE Loss: 0.000176, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.302415
# Epoch 5110, PDE Loss: 0.000176, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.308055
# Epoch 5120, PDE Loss: 0.000175, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.312497
# Epoch 5130, PDE Loss: 0.000175, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.315394
# Epoch 5140, PDE Loss: 0.000174, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317370
# Epoch 5150, PDE Loss: 0.000174, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.316692
# Epoch 5160, PDE Loss: 0.000173, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320291
# Epoch 5170, PDE Loss: 0.000173, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.321692
# Epoch 5180, PDE Loss: 0.000173, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.326466
# Epoch 5190, PDE Loss: 0.000172, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.328091
# Epoch 5200, PDE Loss: 0.000171, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325228
# Epoch 5210, PDE Loss: 0.000171, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320325
# Epoch 5220, PDE Loss: 0.000170, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.316398
# Epoch 5230, PDE Loss: 0.000170, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.313508
# Epoch 5240, PDE Loss: 0.000170, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.310441
# Epoch 5250, PDE Loss: 0.000170, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.312479
# Epoch 5260, PDE Loss: 0.000169, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.312387
# Epoch 5270, PDE Loss: 0.000169, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.316427
# Epoch 5280, PDE Loss: 0.000169, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.314179
# Epoch 5290, PDE Loss: 0.000169, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.311948
# Epoch 5300, PDE Loss: 0.000168, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.315681
# Epoch 5310, PDE Loss: 0.000168, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317682
# Epoch 5320, PDE Loss: 0.000168, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317561
# Epoch 5330, PDE Loss: 0.000167, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.313464
# Epoch 5340, PDE Loss: 0.000167, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.311064
# Epoch 5350, PDE Loss: 0.000166, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.311813
# Epoch 5360, PDE Loss: 0.000166, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.313296
# Epoch 5370, PDE Loss: 0.000165, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.313922
# Epoch 5380, PDE Loss: 0.000165, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.316821
# Epoch 5390, PDE Loss: 0.000165, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317776
# Epoch 5400, PDE Loss: 0.000164, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320786
# Epoch 5410, PDE Loss: 0.000164, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.322228
# Epoch 5420, PDE Loss: 0.000164, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325141
# Epoch 5430, PDE Loss: 0.000163, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325384
# Epoch 5440, PDE Loss: 0.000163, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.326116
# Epoch 5450, PDE Loss: 0.000163, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.324553
# Epoch 5460, PDE Loss: 0.000163, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325429
# Epoch 5470, PDE Loss: 0.000162, BC vel. Loss: 0.000001, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320841
# Epoch 5480, PDE Loss: 0.000162, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.314865
# Epoch 5490, PDE Loss: 0.000161, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.314239
# Epoch 5500, PDE Loss: 0.000161, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.313743
# Epoch 5510, PDE Loss: 0.000161, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.313996
# Epoch 5520, PDE Loss: 0.000160, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.314491
# Epoch 5530, PDE Loss: 0.000160, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.315380
# Epoch 5540, PDE Loss: 0.000160, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.321194
# Epoch 5550, PDE Loss: 0.000159, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320086
# Epoch 5560, PDE Loss: 0.000158, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320473
# Epoch 5570, PDE Loss: 0.000158, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.323823
# Epoch 5580, PDE Loss: 0.000157, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320562
# Epoch 5590, PDE Loss: 0.000157, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317469
# Epoch 5600, PDE Loss: 0.000156, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.318356
# Epoch 5610, PDE Loss: 0.000156, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.315192
# Epoch 5620, PDE Loss: 0.000156, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.316117
# Epoch 5630, PDE Loss: 0.000155, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.318782
# Epoch 5640, PDE Loss: 0.000154, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.315831
# Epoch 5650, PDE Loss: 0.000153, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.317073
# Epoch 5660, PDE Loss: 0.000153, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.316243
# Epoch 5670, PDE Loss: 0.000153, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.315658
# Epoch 5680, PDE Loss: 0.000152, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.318129
# Epoch 5690, PDE Loss: 0.000152, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.319021
# Epoch 5700, PDE Loss: 0.000151, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.320314
# Epoch 5710, PDE Loss: 0.000151, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.323241
# Epoch 5720, PDE Loss: 0.000151, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.324881
# Epoch 5730, PDE Loss: 0.000151, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325498
# Epoch 5740, PDE Loss: 0.000150, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.326285
# Epoch 5750, PDE Loss: 0.000150, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329123
# Epoch 5760, PDE Loss: 0.000150, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329207
# Epoch 5770, PDE Loss: 0.000149, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329255
# Epoch 5780, PDE Loss: 0.000149, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.327354
# Epoch 5790, PDE Loss: 0.000149, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.325645
# Epoch 5800, PDE Loss: 0.000149, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.327686
# Epoch 5810, PDE Loss: 0.000148, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.330902
# Epoch 5820, PDE Loss: 0.000148, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.332535
# Epoch 5830, PDE Loss: 0.000148, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.331852
# Epoch 5840, PDE Loss: 0.000148, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.331675
# Epoch 5850, PDE Loss: 0.000147, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329985
# Epoch 5860, PDE Loss: 0.000147, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329517
# Epoch 5870, PDE Loss: 0.000146, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.332250
# Epoch 5880, PDE Loss: 0.000146, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329769
# Epoch 5890, PDE Loss: 0.000145, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329450
# Epoch 5900, PDE Loss: 0.000145, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329384
# Epoch 5910, PDE Loss: 0.000145, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.329781
# Epoch 5920, PDE Loss: 0.000144, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.330762
# Epoch 5930, PDE Loss: 0.000144, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.333411
# Epoch 5940, PDE Loss: 0.000144, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.335541
# Epoch 5950, PDE Loss: 0.000144, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.337225
# Epoch 5960, PDE Loss: 0.000144, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.339749
# Epoch 5970, PDE Loss: 0.000143, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.340462
# Epoch 5980, PDE Loss: 0.000143, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.343363
# Epoch 5990, PDE Loss: 0.000143, BC vel. Loss: 0.000000, BC pres. Loss: 0.000000, DATA Loss: N/A, L2 Error: 3.346672

# %% [markdown]
# - Tiempo de entrenamiento (6000 epochs): 111m

# %%
if USE_DATA:
    loss_history = [pde + bc_vel + bc_p + data for pde, bc_vel, bc_p, data in zip(pde_loss_history, bc_vel_loss_history, bc_p_loss_history, data_loss_history)]
else:
    loss_history = [pde + bc_vel + bc_p for pde, bc_vel, bc_p in zip(pde_loss_history, bc_vel_loss_history, bc_p_loss_history)]

# axs = 5 if USE_DATA else 4
axs = 6 if USE_DATA else 5
fig, axs = plt.subplots(1, axs, figsize=(5*axs, 5))
axs[0].plot(loss_history, label='Total Loss')
axs[0].set_title('Total Loss')
axs[1].plot(pde_loss_history, label='PDE Loss')
axs[1].set_title('PDE Loss')
axs[2].plot(bc_vel_loss_history, label='BC Velocity Loss')
axs[2].set_title('BC Velocity Loss')
axs[3].plot(bc_p_loss_history, label='BC Pressure Loss')
axs[3].set_title('BC Pressure Loss')
if USE_DATA:
    axs[4].plot(data_loss_history, label='DATA Loss')
    axs[4].set_title('DATA Loss')
axs[5 if USE_DATA else 4].plot(l2_error, label='L2 Error')
axs[5 if USE_DATA else 4].set_title('L2 Error')
[ax.set_yscale('log') for ax in axs]
[ax.set_xscale('log') for ax in axs]

fig.suptitle("x10 puntos de colocación")
# Out:
# Text(0.5, 0.98, 'x10 puntos de colocación')

# %%
y_pred = pinn(torch.tensor(X_data_all, dtype=torch.float64).to(device)).detach().cpu().numpy()
pred_df = pd.DataFrame({
    'x': X_data_all[:, 0].numpy(),
    'y': X_data_all[:, 1].numpy(),
    'p': y_pred[:, 0],
    'u': y_pred[:, 1],
    'v': y_pred[:, 2],
})

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
[ax.set_xlim(0,1) for ax in axs]
[ax.set_ylim(0,1) for ax in axs]
[
    ax.imshow(
        griddata(
            # np.column_stack((pred_df['x'], pred_df['y'])),
            X_data_all.numpy(),
            pred_df[col],
            np.meshgrid(np.linspace(0, 1, 1000), np.linspace(0, 1, 1000)),
            method='cubic'
        ),
        # pred_df.pivot_table(index='y', columns='x', values=col).values,
        origin='lower',
        extent=(0, 1, 0, 1),
        cmap='jet'
    )
    for ax, col in zip(axs, ['p', 'u', 'v'])
]
axs[0].set_title("Presión")
axs[1].set_title("Velocidad U")
axs[2].set_title("Velocidad V")

fig.colorbar(axs[0].images[0], ax=axs[0], label='p')
fig.colorbar(axs[1].images[0], ax=axs[1], label='u')
fig.colorbar(axs[2].images[0], ax=axs[2], label='v')

fig.suptitle("x10 puntos de colocación")
# Out:
# /tmp/ipykernel_392916/3139757739.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = pinn(torch.tensor(X_data_all, dtype=torch.float64).to(device)).detach().cpu().numpy()
# Text(0.5, 0.98, 'x10 puntos de colocación')

# %%
error_l2 = linalg.norm(y_data_all.numpy() - y_pred)
print("Error L2:", error_l2)
# Out:
# Error L2: 3.3491691223096596

# %%
error_abs = y_data_all.numpy() - y_pred
error_abs_df = pd.DataFrame(np.hstack((X_data_all, error_abs)), columns=['x', 'y', 'p_err', 'u_err', 'v_err'])
print(error_abs_df.head())

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
[ax.set_xlim(0,1) for ax in axs]
[ax.set_ylim(0,1) for ax in axs]
[
    ax.imshow(
        griddata(
            # np.column_stack((pred_df['x'], pred_df['y'])),
            X_data_all.numpy(),
            error_abs_df[col],
            np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100)),
            method='cubic'
        ),
        # pred_df.pivot_table(index='y', columns='x', values=col).values,
        origin='lower',
        extent=(0, 1, 0, 1),
        cmap='jet'
    )
    # for ax, col in zip(axs, ['p', 'u', 'v'])
    for ax, col in zip(axs, ['p_err', 'u_err', 'v_err'])
]
fig.colorbar(axs[0].images[0], ax=axs[0], label='p Error')
fig.colorbar(axs[1].images[0], ax=axs[1], label='u Error')
fig.colorbar(axs[2].images[0], ax=axs[2], label='v Error')

fig.suptitle("x10 puntos de colocación")
# Out:
#       x    y     p_err     u_err     v_err
# 0  0.00  0.0 -0.000001  0.001014 -0.002337
# 1  0.01  0.0  0.000269  0.000502 -0.002070
# 2  0.02  0.0  0.000496  0.000061 -0.001805
# 3  0.03  0.0  0.000654 -0.000312 -0.001548
# 4  0.04  0.0  0.000749 -0.000621 -0.001300
# Text(0.5, 0.98, 'x10 puntos de colocación')

# %%
X_x05 = X_data_all[X_data_all[:, 0] == 0.5]
X_y05 = X_data_all[X_data_all[:, 1] == 0.5]
y_data_x05 = y_data_all[X_data_all[:, 0] == 0.5]
y_pred_x05 = y_pred[X_data_all[:, 0] == 0.5]
y_data_y05 = y_data_all[X_data_all[:, 1] == 0.5]
y_pred_y05 = y_pred[X_data_all[:, 1] == 0.5]

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].plot(X_x05[:, 1].numpy(), y_data_x05[:, 0].numpy(), label='P (ground truth)', color='red'   )
axs[0].plot(X_x05[:, 1].numpy(), y_data_x05[:, 1].numpy(), label='U (ground truth)', color='blue'  )
axs[0].plot(X_x05[:, 1].numpy(), y_data_x05[:, 2].numpy(), label='V (ground truth)', color='violet')
axs[0].plot(X_x05[:, 1].numpy(), y_pred_x05[:, 0], label='P (predicho)', linestyle='dashed', color='red'   )
axs[0].plot(X_x05[:, 1].numpy(), y_pred_x05[:, 1], label='U (predicho)', linestyle='dashed', color='blue'  )
axs[0].plot(X_x05[:, 1].numpy(), y_pred_x05[:, 2], label='V (predicho)', linestyle='dashed', color='violet')
axs[0].legend()
axs[0].set_title('Sección vertical en x=0.5')
axs[0].set_xlabel('Y axis')

axs[1].plot(X_y05[:, 0].numpy(), y_data_y05[:, 0].numpy(), label='P (ground truth)', color='red'   )
axs[1].plot(X_y05[:, 0].numpy(), y_data_y05[:, 1].numpy(), label='U (ground truth)', color='blue'  )
axs[1].plot(X_y05[:, 0].numpy(), y_data_y05[:, 2].numpy(), label='V (ground truth)', color='violet')
axs[1].plot(X_y05[:, 0].numpy(), y_pred_y05[:, 0], label='P (predicho)', linestyle='dashed', color='red'   )
axs[1].plot(X_y05[:, 0].numpy(), y_pred_y05[:, 1], label='U (predicho)', linestyle='dashed', color='blue'  )
axs[1].plot(X_y05[:, 0].numpy(), y_pred_y05[:, 2], label='V (predicho)', linestyle='dashed', color='violet')
axs[1].legend()
axs[1].set_title('Sección vertical en y=0.5')
axs[1].set_xlabel('X axis')

[ax.set_xlim(0,1) for ax in axs]
fig.suptitle("x10 puntos de colocación")
# Out:
# Text(0.5, 0.98, 'x10 puntos de colocación')
